# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"./data/online_retail_listing.csv", on_bad_lines='skip', encoding='latin', sep=';')

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1048570  580501     23284        DOORMAT KEEP CALM AND COME IN         2
# 1048571  580501     22507         MEMO BOARD RETROSPOT  DESIGN         3
# 1048572  580502     22469                HEART OF WICKER SMALL         3
# 1048573  580502     23489                VINTAGE BELLS GARLAND         2
# 1048574  580502     23046    PAPER LANTERN 9 POINT DELUXE STAR         1
#
#              InvoiceDate Price  Customer ID         Country
# 0        1.12.2009 07:45  6,95      13085.0  United Kingdom
# 1        1.12.2009 07:45  6,75      13085.0  United Kingdom
# 2        1.12.2009 07:45  6,75      13085.0  United Kingdom
# 3        1.12.2009 07:45   2,1      13085.0  United Kingdom
# 4        1.12.2009 07:45  1,25      13085.0  United Kingdom
# ...                  ...   ...          ...             ...
# 1048570  4.12.2011 13:00  8,25      14546.0  United Kingdom
# 1048571  4.12.2011 13:00  4,95      14546.0  United Kingdom
# 1048572  4.12.2011 13:15  1,65      16931.0  United Kingdom
# 1048573  4.12.2011 13:15  2,89      16931.0  United Kingdom
# 1048574  4.12.2011 13:15  6,65      16931.0  United Kingdom
#
# [1048575 rows x 8 columns]

# %%
df.Description.nunique()
# Out:
# 5697

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format="%d.%m.%Y %H:%M")

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

target = 'Price'
X, y = df.drop('Price', axis=1), df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2,
                                                    random_state=0)

# %%
X_train.shape
# Out:
# (838860, 7)

# %%
X_test.shape
# Out:
# (209715, 7)

# %%
X_train
# Out:
#         Invoice StockCode                         Description  Quantity  \
# 592908   541830     20707        CRAZY DAISY HEART DECORATION         1
# 184386   506956     21918    SET 12 KIDS COLOUR  CHALK STICKS         4
# 1021782  578344     23168        CLASSIC CAFE SUGAR DISPENSER         2
# 59606    494768     22066              LOVE HEART TRINKET POT        12
# 93792    498159    84279B     CHERRY BLOSSOM DECORATIVE FLASK         4
# ...         ...       ...                                 ...       ...
# 963395   574298     22278  OVERNIGHT BAG VINTAGE ROSE PAISLEY         1
# 117952   500616     21895       POTTING SHED SOW 'N' GROW SET         4
# 435829   530999     21231      SWEETHEART CERAMIC TRINKET BOX        12
# 305711   519217     22432             WATERING CAN PINK BUNNY         6
# 985772   575905     22089       PAPER BUNTING VINTAGE PAISLEY         6
#
#                 InvoiceDate  Customer ID         Country
# 592908  2011-01-21 17:09:00          NaN  United Kingdom
# 184386  2010-05-05 11:51:00      16415.0  United Kingdom
# 1021782 2011-11-24 09:21:00          NaN  United Kingdom
# 59606   2010-01-18 12:42:00      18057.0  United Kingdom
# 93792   2010-02-17 11:49:00      17646.0  United Kingdom
# ...                     ...          ...             ...
# 963395  2011-11-03 15:56:00          NaN  United Kingdom
# 117952  2010-03-09 10:45:00      15437.0  United Kingdom
# 435829  2010-11-05 11:25:00      14911.0            EIRE
# 305711  2010-08-15 11:51:00      16873.0  United Kingdom
# 985772  2011-11-11 15:49:00      13732.0  United Kingdom
#
# [838860 rows x 7 columns]

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'USA', 'Belgium', 'Australia', 'EIRE',
#        'Germany', 'Portugal', 'Japan', 'Denmark', 'Nigeria',
#        'Netherlands', 'Poland', 'Spain', 'Channel Islands', 'Italy',
#        'Cyprus', 'Greece', 'Norway', 'Austria', 'Sweden',
#        'United Arab Emirates', 'Finland', 'Switzerland', 'Unspecified',
#        'Malta', 'Bahrain', 'RSA', 'Bermuda', 'Hong Kong', 'Singapore',
#        'Thailand', 'Israel', 'Lithuania', 'West Indies', 'Lebanon',
#        'Korea', 'Brazil', 'Canada', 'Iceland', 'Saudi Arabia',
#        'Czech Republic', 'European Community'], dtype=object)

# %%
lista = ['Invoice','StockCode', 'InvoiceDate', 'Description','Country']

data = df.drop(lista, axis=1)
data = pd.DataFrame(data)

# %%
data['Price'] = data['Price'].str.replace(',','.')

# %%
data['Price'] = data['Price'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Quantity     1048575 non-null  int64
#  1   Price        1048575 non-null  float64
#  2   Customer ID  811893 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 24.0 MB

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#          Quantity  Price  Customer ID
# 0              12   6.95      13085.0
# 1              12   6.75      13085.0
# 2              12   6.75      13085.0
# 3              48   2.10      13085.0
# 4              24   1.25      13085.0
# ...           ...    ...          ...
# 1048570         2   8.25      14546.0
# 1048571         3   4.95      14546.0
# 1048572         3   1.65      16931.0
# 1048573         2   2.89      16931.0
# 1048574         1   6.65      16931.0
#
# [1048575 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Quantity     1048575 non-null  int64
#  1   Price        1048575 non-null  float64
#  2   Customer ID  1048575 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 24.0 MB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
X, y= data.drop(target, axis=1), data[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn import datasets, linear_model

lasso = linear_model.Lasso()


pipe = Pipeline([('Linear', LinearRegression())])

pipe2 = Pipeline([('Standard Scaler', StandardScaler())])

# %%
def ejecutar(pipe, X_train, X_test, y_train, y_test):
    pipe.fit(X_train, y_train)
    pred = pipe.predict(X_test)
    print(f"mse = {mean_squared_error(y_test, pred)}")
    print('Cross validation', cross_val_score(lasso, X_test, y_test))


def ejecutar2(pipe, X_train, X_test, y_train, y_test):
    pipe.fit(X_train, y_train)
    print(X_train)

# %%
ejecutar(pipe, X_train, X_test, y_train, y_test)
# Out:
# mse = 27011.65658332144
# Cross validation [ 6.65268027e-04  9.61600978e-04  4.34566904e-04 -9.24631764e-05
#  -9.86218692e-06]

# %%
ejecutar2(pipe2, X_train, X_test, y_train, y_test)
# Out:
#         Quantity  Customer ID
# 215865         4      13728.0
# 740813         2      14498.0
# 550587         6      16873.0
# 269537        43      15673.0
# 42998          2          0.0
# ...          ...          ...
# 223890        12      14208.0
# 393794         1      15967.0
# 104152         1          0.0
# 985479         8      17088.0
# 941076         2          0.0
#
# [838860 rows x 2 columns]

# %%
pipe2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Standard Scaler', StandardScaler())])

# %%
pipe
# Out:
# Pipeline(steps=[('Linear', LinearRegression())])
