# %%
import pandas as pd
import numpy as np

from tensorflow.keras.callbacks import EarlyStopping

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


import tensorflow 
import seaborn as sns

from tensorflow import keras
from keras.layers import Dense
from sklearn.metrics import classification_report, confusion_matrix

import cv2

import numpy as np


from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"./online_retail_listing.csv", on_bad_lines='skip', encoding='latin', sep=';')

# %%
df.Description.nunique()
# Out:
# 5697

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format="%d.%m.%Y %H:%M")

# %%
target = 'Price'
X, y = df.drop('Price', axis=1), df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2,
                                                    random_state=0)

# %%
X_train.shape
# Out:
# (838860, 7)

# %%
X_test.shape
# Out:
# (209715, 7)

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'USA', 'Belgium', 'Australia', 'EIRE',
#        'Germany', 'Portugal', 'Japan', 'Denmark', 'Nigeria',
#        'Netherlands', 'Poland', 'Spain', 'Channel Islands', 'Italy',
#        'Cyprus', 'Greece', 'Norway', 'Austria', 'Sweden',
#        'United Arab Emirates', 'Finland', 'Switzerland', 'Unspecified',
#        'Malta', 'Bahrain', 'RSA', 'Bermuda', 'Hong Kong', 'Singapore',
#        'Thailand', 'Israel', 'Lithuania', 'West Indies', 'Lebanon',
#        'Korea', 'Brazil', 'Canada', 'Iceland', 'Saudi Arabia',
#        'Czech Republic', 'European Community'], dtype=object)

# %%
lista = ['Invoice','StockCode', 'InvoiceDate', 'Description','Country']

data = df.drop(lista, axis=1)
data = pd.DataFrame(data)

# %%
data['Price'] = data['Price'].str.replace(',','.')

# %%
data['Price'] = data['Price'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Quantity     1048575 non-null  int64
#  1   Price        1048575 non-null  float64
#  2   Customer ID  811893 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 24.0 MB

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#          Quantity  Price  Customer ID
# 0              12   6.95      13085.0
# 1              12   6.75      13085.0
# 2              12   6.75      13085.0
# 3              48   2.10      13085.0
# 4              24   1.25      13085.0
# ...           ...    ...          ...
# 1048570         2   8.25      14546.0
# 1048571         3   4.95      14546.0
# 1048572         3   1.65      16931.0
# 1048573         2   2.89      16931.0
# 1048574         1   6.65      16931.0
#
# [1048575 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Quantity     1048575 non-null  int64
#  1   Price        1048575 non-null  float64
#  2   Customer ID  1048575 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 24.0 MB

# %%
lr = LinearRegression()

# %%
X, y= data.drop(target, axis=1), data[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)

# %%
lasso = linear_model.Lasso()


pipe = Pipeline([('Linear', LinearRegression())])

pipe2 = Pipeline([('Standard Scaler', StandardScaler())])

# %%
def ejecutar(pipe, X_train, X_test, y_train, y_test):
    pipe.fit(X_train, y_train)
    pred = pipe.predict(X_test)
    print(f"mse = {mean_squared_error(y_test, pred)}")
    print('Cross validation', cross_val_score(lasso, X_test, y_test))


def ejecutar2(pipe, X_train, X_test, y_train, y_test):
    pipe.fit(X_train, y_train)
    print(X_train)

# %%
ejecutar(pipe, X_train, X_test, y_train, y_test)
# Out:
# mse = 27011.65658332144
# Cross validation [ 6.65268027e-04  9.61600978e-04  4.34566904e-04 -9.24631764e-05
#  -9.86218692e-06]

# %%
ejecutar2(pipe2, X_train, X_test, y_train, y_test)
# Out:
#         Quantity  Customer ID
# 215865         4      13728.0
# 740813         2      14498.0
# 550587         6      16873.0
# 269537        43      15673.0
# 42998          2          0.0
# ...          ...          ...
# 223890        12      14208.0
# 393794         1      15967.0
# 104152         1          0.0
# 985479         8      17088.0
# 941076         2          0.0
#
# [838860 rows x 2 columns]

# %%
pipe2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Standard Scaler', StandardScaler())])

# %%
pipe
# Out:
# Pipeline(steps=[('Linear', LinearRegression())])

# %%
# Ruta donde están almacenadas las imágenes
dataset_dir = r'./asl_dataset'

# %%
model = keras.Sequential([ 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dense(64, activation='relu'),   
    keras.layers.Dense(36, activation='softmax') # Capa de salida con 10 neuronas (10 clases)
])

# %%
clases = sorted(os.listdir(dataset_dir))  # ['0', '1', ..., '9', 'A', 'B', ..., 'Z']
num_clases = len(clases)
X = []
y = []

# %%
for label, clase in enumerate(clases):
    folder_path = os.path.join(dataset_dir, clase)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Convertimos a escala de grises
        img = cv2.resize(img, (64, 64))  # Redimensionamos a 64x64 píxeles
        X.append(img.flatten())  # Convertimos la imagen en un vector
        y.append(label)  # Guardamos la etiqueta de la clase
# Convertir a arrays de numpy
X = np.array(X)
y = np.array(y)
# Mezclar los datos aleatoriamente
indices = np.arange(len(X))
np.random.shuffle(indices)
# Aplicar el desorden a X e y
X = X[indices]
y = y[indices]
# Dividir en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
print(f"Datos cargados y mezclados: {X.shape[0]} imágenes, {num_clases} clases")
print(f"Train: {X_train.shape[0]} imágenes | Test: {X_test.shape[0]} imágenes")
# Out:
# Datos cargados y mezclados: 2515 imágenes, 36 clases
# Train: 2012 imágenes | Test: 503 imágenes

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2, stratify=y)

# %%
pipeline = Pipeline([('model', model)])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'],
             )

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


model.fit(X_train, y_train, epochs=36, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9682 - loss: 0.0921 - val_accuracy: 0.8907 - val_loss: 1.0220
# Epoch 2/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9771 - loss: 0.0747 - val_accuracy: 0.9066 - val_loss: 0.9707
# Epoch 3/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0537 - val_accuracy: 0.8986 - val_loss: 1.0051
# Epoch 4/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0433 - val_accuracy: 0.9046 - val_loss: 1.1430
# Epoch 5/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9798 - loss: 0.0508 - val_accuracy: 0.9046 - val_loss: 1.1782
# Epoch 6/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9736 - loss: 0.1387 - val_accuracy: 0.8330 - val_loss: 2.1088
# Epoch 7/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9483 - loss: 0.4894 - val_accuracy: 0.8847 - val_loss: 0.9692
# Epoch 8/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9747 - loss: 0.0933 - val_accuracy: 0.8728 - val_loss: 1.2856
# Epoch 9/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9515 - loss: 0.2391 - val_accuracy: 0.8787 - val_loss: 1.1622
# Epoch 10/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1706 - val_accuracy: 0.8728 - val_loss: 2.1520
# Epoch 11/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9512 - loss: 0.4612 - val_accuracy: 0.8827 - val_loss: 1.6627
# Epoch 12/36
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9410 - loss: 0.2459 - val_accuracy: 0.8907 - val_loss: 1.9437
